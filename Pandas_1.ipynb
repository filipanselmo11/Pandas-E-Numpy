# %%
import pandas as pd
data = pd.read_csv('house_data1.csv')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0       3.0       1.00         1180
# 1  6414100192  20141209T000000  538000.0       3.0       2.25         2570
# 2  5631500400  20150225T000000  180000.0       2.0       1.00          770
# 3  2487200875  20141209T000000  604000.0       4.0       3.00         1960
# 4  1954400510  20150218T000000  510000.0       3.0       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
data.count()
# Out:
# id               21613
# date             21613
# price            21613
# bedrooms         21609
# bathrooms        21613
# sqft_living      21613
# sqft_lot         21613
# floors           21612
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21613
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# dtype: int64

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21609.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370910      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930084      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21612.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494332      0.007542      0.234303      3.409430
# ...

# %%
pd.value_counts(data['bedrooms'])
# Out:
# 3.0     9822
# 4.0     6881
# 2.0     2759
# 5.0     1601
# 6.0      272
# 1.0      199
# 7.0       38
# 8.0       13
# 0.0       13
# 9.0        6
# 10.0       3
# 11.0       1
# 33.0       1
# Name: bedrooms, dtype: int64

# %%
data.loc[data['bedrooms']==3]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0       3.0       1.00
# 1      6414100192  20141209T000000   538000.0       3.0       2.25
# 4      1954400510  20150218T000000   510000.0       3.0       2.00
# 6      1321400060  20140627T000000   257500.0       3.0       2.25
# 7      2008000270  20150115T000000   291850.0       3.0       1.50
# 8      2414600126  20150415T000000   229500.0       3.0       1.00
# 9      3793500160  20150312T000000   323000.0       3.0       2.50
# 10     1736800520  20150403T000000   662500.0       3.0       2.50
# 12      114101516  20140528T000000   310000.0       3.0       1.00
# 13     6054650070  20141007T000000   400000.0       3.0       1.75
# 16     1875500060  20140731T000000   395000.0       3.0       2.00
# 19     7983200060  20150424T000000   230000.0       3.0       1.00
# 21     2524049179  20140826T000000  2000000.0       3.0       2.75
# ...

# %%
data.loc[(data['bedrooms']==3) & (data['bathrooms']>2)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1      6414100192  20141209T000000   538000.0       3.0       2.25
# 6      1321400060  20140627T000000   257500.0       3.0       2.25
# 9      3793500160  20150312T000000   323000.0       3.0       2.50
# 10     1736800520  20150403T000000   662500.0       3.0       2.50
# 21     2524049179  20140826T000000  2000000.0       3.0       2.75
# 24     3814700200  20141120T000000   329000.0       3.0       2.25
# 30     8562750320  20141110T000000   580500.0       3.0       2.50
# 35     9547205180  20140613T000000   696000.0       3.0       2.50
# 45     8035350320  20140718T000000   488000.0       3.0       2.50
# 49      822039084  20150311T000000  1350000.0       3.0       2.50
# 60     1516000055  20141210T000000   650000.0       3.0       2.25
# 64     1189001180  20140603T000000   425000.0       3.0       2.25
# 65     3253500160  20141120T000000   317625.0       3.0       2.75
# ...

# %%
data.sort_values()
