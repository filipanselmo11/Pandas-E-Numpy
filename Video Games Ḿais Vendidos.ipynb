# %%
dataset = open('vgsales.csv')

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
videogames = pd.read_csv('vgsales.csv')

# %%
print("######")
videogames.head(900)
# Out:
# ######
#      Rank                                          Name Platform    Year  \
# 0       1                                    Wii Sports      Wii  2006.0
# 1       2                             Super Mario Bros.      NES  1985.0
# 2       3                                Mario Kart Wii      Wii  2008.0
# 3       4                             Wii Sports Resort      Wii  2009.0
# 4       5                      Pokemon Red/Pokemon Blue       GB  1996.0
# 5       6                                        Tetris       GB  1989.0
# 6       7                         New Super Mario Bros.       DS  2006.0
# 7       8                                      Wii Play      Wii  2006.0
# 8       9                     New Super Mario Bros. Wii      Wii  2009.0
# 9      10                                     Duck Hunt      NES  1984.0
# 10     11                                    Nintendogs       DS  2005.0
# 11     12                                 Mario Kart DS       DS  2005.0
# 12     13                   Pokemon Gold/Pokemon Silver       GB  1999.0
# 13     14                                       Wii Fit      Wii  2007.0
# 14     15                                  Wii Fit Plus      Wii  2009.0
# 15     16                            Kinect Adventures!     X360  2010.0
# 16     17                            Grand Theft Auto V      PS3  2013.0
# 17     18                 Grand Theft Auto: San Andreas      PS2  2004.0
# 18     19                             Super Mario World     SNES  1990.0
# 19     20  Brain Age: Train Your Brain in Minutes a Day       DS  2005.0
# 20     21                 Pokemon Diamond/Pokemon Pearl       DS  2006.0
# 21     22                              Super Mario Land       GB  1989.0
# 22     23                           Super Mario Bros. 3      NES  1988.0
# 23     24                            Grand Theft Auto V     X360  2013.0
# 24     25                   Grand Theft Auto: Vice City      PS2  2002.0
# 25     26                 Pokemon Ruby/Pokemon Sapphire      GBA  2002.0
# 26     27                   Pokemon Black/Pokemon White       DS  2010.0
# 27     28   Brain Age 2: More Training in Minutes a Day       DS  2005.0
# 28     29                        Gran Turismo 3: A-Spec      PS2  2001.0
# 29     30                Call of Duty: Modern Warfare 3     X360  2011.0
# ..    ...                                           ...      ...     ...
# 870   872               Tom Clancy's Rainbow Six: Vegas     X360  2006.0
# 871   873                                       Destiny     X360  2014.0
# 872   874                              Crash Nitro Kart      PS2  2003.0
# 873   875                 Grand Theft Auto: San Andreas       XB  2005.0
# 874   876                        Star Wars: Dark Forces       PC  1994.0
# 875   877                             NBA Street Vol. 2      PS2  2003.0
# 876   878                              Def Jam Vendetta      PS2  2003.0
# 877   879                                FIFA Soccer 09     X360  2008.0
# 878   880                 Who wants to be a millionaire       PC  1999.0
# 879   881                Scooby Doo and the Cyber Chase       PS  2001.0
# 880   882                                      Alleyway       GB  1989.0
# 881   883                      Dragon Ball Z: Budokai 3      PS2  2004.0
# 882   884                                    Jet Moto 2       PS  1997.0
# 883   885                      Tom Clancy's Ghost Recon      PS2  2002.0
# 884   886                                 X-Men Legends      PS2  2004.0
# 885   887                        Batman: Arkham Origins     X360  2013.0
# 886   888                       Guitar Hero: World Tour      PS3  2008.0
# 887   889                              Mortal Kombat II     SNES  1993.0
# 888   890                              Virtua Fighter 2      SAT  1995.0
# 889   891                                     Tetris DX       GB  1998.0
# 890   892                 Mortal Kombat vs. DC Universe     X360  2008.0
# 891   893                                    Watch Dogs      PS3  2014.0
# 892   894                          Mario Super Sluggers      Wii  2008.0
# 893   895                            Tomb Raider (2013)     X360  2013.0
# 894   896           The Legend of Zelda: Oracle of Ages       GB  2001.0
# 895   897                         Need for Speed: Shift     X360  2009.0
# 896   898                                      Monopoly      Wii  2008.0
# 897   899                                   Red Faction      PS2  2001.0
# 898   900                        The Sims: Makin' Magic       PC  2003.0
# 899   901                                  MX Unleashed      PS2  2004.0
#
#             Genre                               Publisher  NA_Sales  EU_Sales  \
# 0          Sports                                Nintendo     41.49     29.02
# 1        Platform                                Nintendo     29.08      3.58
# 2          Racing                                Nintendo     15.85     12.88
# 3          Sports                                Nintendo     15.75     11.01
# 4    Role-Playing                                Nintendo     11.27      8.89
# 5          Puzzle                                Nintendo     23.20      2.26
# 6        Platform                                Nintendo     11.38      9.23
# 7            Misc                                Nintendo     14.03      9.20
# 8        Platform                                Nintendo     14.59      7.06
# 9         Shooter                                Nintendo     26.93      0.63
# 10     Simulation                                Nintendo      9.07     11.00
# 11         Racing                                Nintendo      9.81      7.57
# 12   Role-Playing                                Nintendo      9.00      6.18
# 13         Sports                                Nintendo      8.94      8.03
# 14         Sports                                Nintendo      9.09      8.59
# 15           Misc                  Microsoft Game Studios     14.97      4.94
# 16         Action                    Take-Two Interactive      7.01      9.27
# 17         Action                    Take-Two Interactive      9.43      0.40
# 18       Platform                                Nintendo     12.78      3.75
# 19           Misc                                Nintendo      4.75      9.26
# 20   Role-Playing                                Nintendo      6.42      4.52
# 21       Platform                                Nintendo     10.83      2.71
# 22       Platform                                Nintendo      9.54      3.44
# 23         Action                    Take-Two Interactive      9.63      5.31
# 24         Action                    Take-Two Interactive      8.41      5.49
# 25   Role-Playing                                Nintendo      6.06      3.90
# 26   Role-Playing                                Nintendo      5.57      3.28
# 27         Puzzle                                Nintendo      3.44      5.36
# 28         Racing             Sony Computer Entertainment      6.85      5.09
# 29        Shooter                              Activision      9.03      4.28
# ..            ...                                     ...       ...       ...
# 870       Shooter                                 Ubisoft      1.09      0.65
# 871       Shooter                              Activision      1.30      0.49
# 872        Racing                           Vivendi Games      0.74      1.01
# 873        Action                    Take-Two Interactive      1.26      0.61
# 874       Shooter                               LucasArts      1.09      0.77
# 875        Sports                         Electronic Arts      1.69      0.20
# 876      Fighting                         Electronic Arts      0.95      0.74
# 877        Sports                         Electronic Arts      0.49      1.26
# 878          Misc              Disney Interactive Studios      1.94      0.00
# 879     Adventure                                     THQ      0.59      1.23
# 880        Puzzle                                Nintendo      0.96      0.38
# 881      Fighting                                   Atari      1.09      0.15
# 882        Racing             Sony Computer Entertainment      1.41      0.42
# 883       Shooter                                 Ubisoft      1.42      0.40
# 884  Role-Playing                              Activision      1.00      0.72
# 885        Action  Warner Bros. Interactive Entertainment      1.15      0.61
# 886          Misc                              Activision      1.10      0.56
# 887      Fighting                   Acclaim Entertainment      1.48      0.39
# 888      Fighting                                    Sega      0.34      0.26
# 889        Puzzle                                Nintendo      1.06      0.60
# 890      Fighting                            Midway Games      1.53      0.24
# 891        Action                                 Ubisoft      0.56      0.89
# 892        Sports                                Nintendo      1.51      0.00
# 893        Action                             Square Enix      0.86      0.87
# 894        Action                                Nintendo      0.92      0.53
# 895        Racing                         Electronic Arts      0.73      0.97
# 896          Misc                         Electronic Arts      0.87      0.85
# 897       Shooter                                     THQ      0.76      0.96
# 898    Simulation                         Electronic Arts      1.03      0.80
# 899        Racing                                     THQ      0.94      0.73
#
#      JP_Sales  Other_Sales  Global_Sales
# 0        3.77         8.46         82.74
# 1        6.81         0.77         40.24
# 2        3.79         3.31         35.82
# 3        3.28         2.96         33.00
# 4       10.22         1.00         31.37
# 5        4.22         0.58         30.26
# 6        6.50         2.90         30.01
# 7        2.93         2.85         29.02
# 8        4.70         2.26         28.62
# 9        0.28         0.47         28.31
# 10       1.93         2.75         24.76
# 11       4.13         1.92         23.42
# 12       7.20         0.71         23.10
# 13       3.60         2.15         22.72
# 14       2.53         1.79         22.00
# 15       0.24         1.67         21.82
# 16       0.97         4.14         21.40
# 17       0.41        10.57         20.81
# 18       3.54         0.55         20.61
# 19       4.16         2.05         20.22
# 20       6.04         1.37         18.36
# 21       4.18         0.42         18.14
# 22       3.84         0.46         17.28
# 23       0.06         1.38         16.38
# 24       0.47         1.78         16.15
# 25       5.38         0.50         15.85
# 26       5.65         0.82         15.32
# 27       5.32         1.18         15.30
# 28       1.87         1.16         14.98
# 29       0.13         1.32         14.76
# ..        ...          ...           ...
# 870      0.02         0.20          1.96
# 871      0.00         0.16          1.95
# 872      0.00         0.20          1.95
# 873      0.00         0.09          1.95
# 874      0.00         0.09          1.95
# 875      0.00         0.06          1.95
# 876      0.00         0.25          1.94
# 877      0.01         0.18          1.94
# 878      0.00         0.00          1.94
# 879      0.00         0.13          1.94
# 880      0.55         0.05          1.94
# 881      0.65         0.04          1.94
# 882      0.03         0.07          1.94
# 883      0.00         0.12          1.94
# 884      0.00         0.21          1.93
# 885      0.00         0.17          1.93
# 886      0.00         0.27          1.93
# 887      0.00         0.06          1.93
# 888      1.30         0.03          1.93
# 889      0.20         0.07          1.93
# 890      0.00         0.16          1.93
# 891      0.10         0.37          1.93
# 892      0.29         0.12          1.93
# 893      0.01         0.17          1.92
# 894      0.41         0.06          1.92
# 895      0.01         0.22          1.92
# 896      0.00         0.20          1.92
# 897      0.00         0.20          1.92
# 898      0.00         0.09          1.92
# 899      0.00         0.25          1.92
#
# [900 rows x 11 columns]

# %%
# Tipo de dados em cada coluna
videogames.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
# Quantidade de linhas e coluna no Data Frame
videogames.shape
# Out:
# (16598, 11)

# %%
# Renomeando colunas
videogames.columns = ['Ranking', 'Nome', 'Plataforma', 'Ano', 'Gênero',
                     'Editora', 'Vendas América do Norte', 'Vendas EUA',
                     'Vendas Japão', 'Outras Vendas', 'Venda Global']

# %%
videogames.head(10)
# Out:
#    Ranking                       Nome Plataforma     Ano        Gênero  \
# 0        1                 Wii Sports        Wii  2006.0        Sports
# 1        2          Super Mario Bros.        NES  1985.0      Platform
# 2        3             Mario Kart Wii        Wii  2008.0        Racing
# 3        4          Wii Sports Resort        Wii  2009.0        Sports
# 4        5   Pokemon Red/Pokemon Blue         GB  1996.0  Role-Playing
# 5        6                     Tetris         GB  1989.0        Puzzle
# 6        7      New Super Mario Bros.         DS  2006.0      Platform
# 7        8                   Wii Play        Wii  2006.0          Misc
# 8        9  New Super Mario Bros. Wii        Wii  2009.0      Platform
# 9       10                  Duck Hunt        NES  1984.0       Shooter
#
#     Editora  Vendas América do Norte  Vendas EUA  Vendas Japão  Outras Vendas  \
# 0  Nintendo                    41.49       29.02          3.77           8.46
# 1  Nintendo                    29.08        3.58          6.81           0.77
# 2  Nintendo                    15.85       12.88          3.79           3.31
# 3  Nintendo                    15.75       11.01          3.28           2.96
# 4  Nintendo                    11.27        8.89         10.22           1.00
# 5  Nintendo                    23.20        2.26          4.22           0.58
# 6  Nintendo                    11.38        9.23          6.50           2.90
# 7  Nintendo                    14.03        9.20          2.93           2.85
# 8  Nintendo                    14.59        7.06          4.70           2.26
# 9  Nintendo                    26.93        0.63          0.28           0.47
#
#    Venda Global
# 0         82.74
# 1         40.24
# 2         35.82
# 3         33.00
# 4         31.37
# 5         30.26
# 6         30.01
# 7         29.02
# 8         28.62
# 9         28.31

# %%
# Verificando linhas onde não há ano de lançamento definido
videogames[videogames['Ano'].isnull()].head()
# Out:
#      Ranking                        Nome Plataforma  Ano    Gênero  \
# 179      180             Madden NFL 2004        PS2  NaN    Sports
# 377      378            FIFA Soccer 2004        PS2  NaN    Sports
# 431      432  LEGO Batman: The Videogame        Wii  NaN    Action
# 470      471  wwe Smackdown vs. Raw 2006        PS2  NaN  Fighting
# 607      608              Space Invaders       2600  NaN   Shooter
#
#                                     Editora  Vendas América do Norte  \
# 179                         Electronic Arts                     4.26
# 377                         Electronic Arts                     0.59
# 431  Warner Bros. Interactive Entertainment                     1.86
# 470                                     NaN                     1.57
# 607                                   Atari                     2.36
#
#      Vendas EUA  Vendas Japão  Outras Vendas  Venda Global
# 179        0.26          0.01           0.71          5.23
# 377        2.36          0.04           0.51          3.49
# 431        1.02          0.00           0.29          3.17
# 470        1.02          0.00           0.41          3.00
# 607        0.14          0.00           0.03          2.53

# %%
videogames['Plataforma'].value_counts()
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# GB        98
# NES       98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# PCFX       1
# GG         1
# Name: Plataforma, dtype: int64

# %%
# Os dois pedaços de código abaixo fazem a mesma coisa
titulos_lancados = videogames['Plataforma'].value_counts()
titulos_lancados.plot()

# %%
# Criando um grafico utilizando apenas linhas de codigo
videogames['Plataforma'].value_counts().head(10).plot(kind = 'bar', figsize=(11,5), grid = False, rot = 0, color = 'green')
# Enfeitando o gráfico. Abaixo, definimos um titulo
plt.title('Os 10 videogames com mais títulos lançados')
plt.xlabel('Videogame') # Nomeando o eixo X, onde fica o nome dos videogames
plt.ylabel('Quantidade de jogos lançados')#Nomeando o eixo y, onde fica a quantidade de jogos
plt.show() #Exibindo o gráfico

# %%
# Os 10 jogos mais vendidos da história
top_10_vendidos = videogames[['Nome', 'Venda Global']].head(10).set_index('Nome').sort_values('Venda Global', ascending = True)
top_10_vendidos.plot(kind='barh', figsize=(11,7), grid=False, color='darkred', legend=False)

plt.title('Os 10 jogos mais vendidos no mundo')
plt.xlabel('Total de Vendas (em milhoes de dolares)')
plt.show()

# %%
crosstab_vg = pd.crosstab(videogames['Plataforma'], videogames['Gênero'])
crosstab_vg.head()
# Out:
# Gênero      Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# Plataforma
# 2600            61          2         2     5         9      11       6
# 3DO              0          1         0     0         0       1       0
# 3DS            182         37        14    53        28      20      11
# DC               3         11        12     0         2       0       6
# DS             343        240        36   393        92     238      67
#
# Gênero      Role-Playing  Shooter  Simulation  Sports  Strategy
# Plataforma
# 2600                   0       24           1      12         0
# 3DO                    0        0           1       0         0
# 3DS                   86        7          30      26        15
# DC                     4        3           1      10         0
# DS                   200       42         285     148        79

# %%
crosstab_vg['Total'] = crosstab_vg.sum(axis=1)
crosstab_vg.head()
# Out:
# Gênero      Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# Plataforma
# 2600            61          2         2     5         9      11       6
# 3DO              0          1         0     0         0       1       0
# 3DS            182         37        14    53        28      20      11
# DC               3         11        12     0         2       0       6
# DS             343        240        36   393        92     238      67
#
# Gênero      Role-Playing  Shooter  Simulation  Sports  Strategy  Total
# Plataforma
# 2600                   0       24           1      12         0    133
# 3DO                    0        0           1       0         0      3
# 3DS                   86        7          30      26        15    509
# DC                     4        3           1      10         0     52
# DS                   200       42         285     148        79   2163

# %%
top10_platforms = crosstab_vg[crosstab_vg['Total']>1000].sort_values('Total', ascending = False)
top10_final = top10_platforms.append(pd.DataFrame(top10_platforms.sum(), columns=['total']).T, ignore_index=False)

sns.set(font_scale=1)
plt.figure(figsize=(18,9))
sns.heatmap(top10_final, annot=True, vmax=top10_final.loc[:'PS',:'Strategy'].values.max(), vmin=top10_final.loc[:,:'Strategy'].values.min(), fmt='d')
plt.xlabel('GÊNERO')
plt.ylabel('CONSOLE')
plt.title('QUANTIDADE DE TITULOS POR GÊNERO E CONSOLE')
plt.show()
