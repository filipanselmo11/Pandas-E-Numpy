# %%
import pandas as pd

# %%
#Lendo o arquivo dos usuários
#u_cols = ['user_id', 'age', 'sex', 'occupation', 'zip_code']

# %%
#Lendo o arquivo de rating
r_cols = ['user_id', 'movie_id', 'rating', 'unix_timestamp']
ratings = pd.read_csv('ml-1m/ratings.dat', sep='\t', names=r_cols, encoding='latin-1')

# %%
#Lendo o arquivo de filmes
m_cols = ['movie_id', 'movie_title', 'release_date', 'video_release_date', 'IMDb_url', 'unknow',
         'Action', 'Adventure', 'Animation', 'Children', 'Comedy', 'Crime', 'Documentary', 'Drama',
         'Fantasy', 'Film-Noir', 'Horror', 'Musical', 'Mystery', 'Romance', 'Sci-Fi', 'Thriller',
         'War', 'Western']
movies = pd.read_csv('ml-1m/movies.dat', sep='|', names=m_cols, encoding='latin-1')

# %%
print(users.shape)
users
# Out:
# (6040, 5)
#                      user_id  age  sex  occupation  zip_code
# 0         1::F::1::10::48067  NaN  NaN         NaN       NaN
# 1        2::M::56::16::70072  NaN  NaN         NaN       NaN
# 2        3::M::25::15::55117  NaN  NaN         NaN       NaN
# 3         4::M::45::7::02460  NaN  NaN         NaN       NaN
# 4        5::M::25::20::55455  NaN  NaN         NaN       NaN
# 5         6::F::50::9::55117  NaN  NaN         NaN       NaN
# 6         7::M::35::1::06810  NaN  NaN         NaN       NaN
# 7        8::M::25::12::11413  NaN  NaN         NaN       NaN
# 8        9::M::25::17::61614  NaN  NaN         NaN       NaN
# 9        10::F::35::1::95370  NaN  NaN         NaN       NaN
# 10       11::F::25::1::04093  NaN  NaN         NaN       NaN
# 11      12::M::25::12::32793  NaN  NaN         NaN       NaN
# 12       13::M::45::1::93304  NaN  NaN         NaN       NaN
# 13       14::M::35::0::60126  NaN  NaN         NaN       NaN
# ...
