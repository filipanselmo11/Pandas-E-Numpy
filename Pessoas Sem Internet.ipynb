# %%
dataset = open('kaggle_internet.csv')

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
internet = pd.read_csv('kaggle_internet.csv')

# %%
internet.head(50)
# Out:
#                           county state         GEOID         lon        lat  \
# 0         Anchorage Municipality    AK  05000US02020 -149.274354  61.177549
# 1   Fairbanks North Star Borough    AK  05000US02090 -146.599867  64.690832
# 2      Matanuska-Susitna Borough    AK  05000US02170 -149.407974  62.182173
# 3                 Baldwin County    AL  05000US01003  -87.746067  30.659218
# 4                 Calhoun County    AL  05000US01015  -85.822513  33.771706
# 5                 Cullman County    AL  05000US01043  -86.869267  34.131923
# 6                  DeKalb County    AL  05000US01049  -85.803992  34.460929
# 7                  Elmore County    AL  05000US01051  -86.142739  32.597229
# 8                  Etowah County    AL  05000US01055  -86.034420  34.047638
# 9                 Houston County    AL  05000US01069  -85.296398  31.158193
# 10              Jefferson County    AL  05000US01073  -86.896536  33.553444
# ...

# %%
internet.dtypes
# Out:
# county                       object
# state                        object
# GEOID                        object
# lon                         float64
# lat                         float64
# P_total                       int64
# P_white                     float64
# P_black                     float64
# P_asian                     float64
# P_native                    float64
# P_hawaiian                  float64
# P_others                    float64
# P_below_middle_school       float64
# P_some_high_school          float64
# P_high_school_equivalent    float64
# P_some_college              float64
# P_bachelor_and_above        float64
# P_below_poverty               int64
# median_age                  float64
# gini_index                  float64
# median_household_income       int64
# median_rent_per_income      float64
# percent_no_internet         float64
# dtype: object

# %%
internet.shape
# Out:
# (820, 23)
